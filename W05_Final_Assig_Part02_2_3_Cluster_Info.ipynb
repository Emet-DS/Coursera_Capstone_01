# %% [markdown]
# # Capstone DS Course
# ## Emet Flores
# ### Week 05 - Final Assignment
# ### Part 02_2_3 - Review Clsuter Statistics
# # Notes:
#  -

# %%
# Import necesary libraries
import pandas as pd

# %%
# We update pandas to more format friendly for reading
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Get the additional data that we processed and documented in a CSV file

San_Diego_codes = pd.read_csv ('SD_Target_Zipcodes.csv', sep = ',', index_col=0)

San_Diego_codes.head()
# Out:
#    ZipCode  ZipCodePopulation  HouseholdsPerZipcode  WhitePop  BlackPop  \
# 1    91901              17403                  6345     15466       315
# 2    91902              17653                  5956     12379       757
# 5    91910              75802                 26063     47051      4255
# 6    91911              82999                 24622     48709      4063
# 7    91913              40971                 12133     21126      3018
#
#    HispanicPop  AsianPop  IndianPop  HawaiianPop  OtherPop  ...  \
# 1         2644       564        743          101       856  ...
# 2         7326      2481        272          217      2596  ...
# 5        45275      9351       1229          786     17635  ...
# 6        58816      8051       1208          955     24733  ...
# 7        18109     12528        428          532      6313  ...
#
#    IncomePerHousehold  MedianAge  AverageFamilySize  Latitude  Longitude  \
# ...

# %%
San_Diego_codes.loc[San_Diego_codes['Labels'] == 0,San_Diego_codes.columns[[1] + list(range(2, San_Diego_codes.shape[1]-7))]].describe()
# Out:
#        ZipCodePopulation  HouseholdsPerZipcode  WhitePop  BlackPop  \
# count              22.00                 22.00     22.00     22.00
# mean            57493.86              17533.77  32439.73   5136.45
# std             13271.45               4461.15  10120.81   3633.39
# min             35125.00              10216.00  12288.00   1475.00
# 25%             48235.00              14153.50  25195.75   2792.50
# 50%             56916.50              17457.50  32076.00   4289.50
# 75%             65341.75              20455.50  38476.50   5470.25
# max             82999.00              26063.00  50669.00  16789.00
#
#        HispanicPop  AsianPop  IndianPop  HawaiianPop  OtherPop  MalePop  \
# count        22.00     22.00      22.00        22.00     22.00    22.00
# mean      27073.64   8137.09     984.09       729.05  13519.00 28756.86
# std       13181.03   7513.83     201.42       301.54   6036.00  6654.24
# min       10197.00   1815.00     473.00       246.00   5103.00 16905.00
# ...

# %%
San_Diego_codes.loc[San_Diego_codes['Labels'] == 2,San_Diego_codes.columns[[1] + list(range(2, San_Diego_codes.shape[1]-7))]].describe()
# Out:
#        ZipCodePopulation  HouseholdsPerZipcode  WhitePop  BlackPop  \
# count              16.00                 16.00     16.00     16.00
# mean            13105.69               4879.94  10886.44    404.50
# std              6919.22               2546.69   5952.76    464.88
# min              1048.00                390.00    846.00     12.00
# 25%              9307.25               3330.50   8536.50     96.50
# 50%             13768.00               5382.00  11412.50    247.50
# 75%             17995.00               6523.00  15492.00    493.50
# max             23575.00               9034.00  20030.00   1815.00
#
#        HispanicPop  AsianPop  IndianPop  HawaiianPop  OtherPop  MalePop  \
# count        16.00     16.00      16.00        16.00     16.00    16.00
# mean       2364.56   1282.19     192.19        82.12    852.44  6585.88
# std        2196.49   1063.41     183.30        68.22    781.43  3604.52
# min          40.00     50.00       3.00         0.00      9.00   476.00
# ...

# %%
San_Diego_codes.loc[San_Diego_codes['Labels'] == 4,San_Diego_codes.columns[[1] + list(range(2, San_Diego_codes.shape[1]-7))]].describe()
# Out:
#        ZipCodePopulation  HouseholdsPerZipcode  WhitePop  BlackPop  \
# count              42.00                 42.00     42.00     42.00
# mean            37039.60              14455.48  27975.71   1702.88
# std              9848.14               4315.38   8530.10   1111.74
# min             18858.00               6209.00  13808.00    227.00
# 25%             27899.50              10987.75  21414.75    932.25
# 50%             38703.00              15160.50  27327.50   1395.00
# 75%             45614.25              17398.50  34975.50   2023.00
# max             53422.00              23349.00  46690.00   4932.00
#
#        HispanicPop  AsianPop  IndianPop  HawaiianPop  OtherPop  MalePop  \
# count        42.00     42.00      42.00        42.00     42.00    42.00
# mean       8132.29   4905.17     586.02       302.98   3595.26 18396.79
# std        5212.42   4296.69     307.58       133.41   2575.36  4899.85
# min        2765.00    723.00     252.00        97.00    836.00  9446.00
# ...

# %%
# Get the venue data that we processed and documented in a CSV file

San_Diego_All = pd.read_csv ('SD_All_Data_Target_Zipcodes.csv', sep = ',', index_col=0)

San_Diego_All.head()
# Out:
#    ZipCode  ZipCodePopulation  HouseholdsPerZipcode  WhitePop  BlackPop  \
# 2    91902              17653                  5956     12379       757
# 5    91910              75802                 26063     47051      4255
# 6    91911              82999                 24622     48709      4063
# 7    91913              40971                 12133     21126      3018
# 8    91914              15448                  4331      8790       912
#
#    HispanicPop  AsianPop  IndianPop  HawaiianPop  OtherPop  ...  \
# 2         7326      2481        272          217      2596  ...
# 5        45275      9351       1229          786     17635  ...
# 6        58816      8051       1208          955     24733  ...
# 7        18109     12528        428          532      6313  ...
# 8         7140      4153        168          169      2440  ...
#
#    Persian Restaurant  Ramen Restaurant  Restaurant  Russian Restaurant  \
# ...

# %%
# And reduce our data set to the clusters of interest

sd_subset = San_Diego_All.loc[San_Diego_All['Cluster Labels'] == 7]
sd_subset.shape
# Out:
# (23, 70)

# %%
# Import additional libraries for data vizualization

import numpy as np
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors


from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import folium # map rendering library

# %%
# Center our coordinates for San Diego
address = 'San Diego, CA'

geolocator = Nominatim(user_agent="on_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of San Diego is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of San Diego is 32.7174209, -117.1627714.

# %%
# Lets reuse code from a previous lab
# create map

# And map the clusters of reference
num_clusters = 8

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sd_subset['Latitude'], sd_subset['Longitude'], sd_subset['ZipCode'], sd_subset['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# And reduce our data set to the clusters of interest of demographic data

sd_subset_2 = San_Diego_All.loc[San_Diego_All['Labels'] == 4]
sd_subset_2.shape
# Out:
# (29, 70)

# %%
# Lets reuse code from a previous lab
# create map

# And map the clusters of reference
num_clusters = 5

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sd_subset_2['Latitude'], sd_subset_2['Longitude'], sd_subset_2['ZipCode'], sd_subset_2['Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# And reduce our data set to the clusters of interest of demographic data

sd_subset_3 = San_Diego_All.loc[San_Diego_All['ZipCode'] == 92104]
sd_subset_3.shape
# Out:
# (1, 70)

# %%
# Lets reuse code from a previous lab
# create map

# And map the clusters of reference
num_clusters = 8

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sd_subset_3['Latitude'], sd_subset_3['Longitude'], sd_subset_3['ZipCode'], sd_subset_3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Combining the data for better visualizing results

# And map the clusters of reference
num_clusters = 8

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
# The venue Cluster
for lat, lon, poi, cluster in zip(sd_subset['Latitude'], sd_subset['Longitude'], sd_subset['ZipCode'], sd_subset['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=6,
        popup=label,
        color=rainbow[0],
        fill=True,
        fill_color=rainbow[0],
        fill_opacity=0.0).add_to(map_clusters)
       
# The demographic profil Cluster
for lat, lon, poi, cluster in zip(sd_subset_2['Latitude'], sd_subset_2['Longitude'], sd_subset_2['ZipCode'], sd_subset_2['Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=4,
        popup=label,
        color=rainbow[1],
        fill=True,
        fill_color=rainbow[1],
        fill_opacity=1.0).add_to(map_clusters)
# The succesful French Venue
for lat, lon, poi, cluster in zip(sd_subset_3['Latitude'], sd_subset_3['Longitude'], sd_subset_3['ZipCode'], sd_subset_3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[7],
        fill=True,
        fill_color=rainbow[7],
        fill_opacity=0.0).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# And view aditional data of interest AFFLUENT demographic data

sd_subset_4 = San_Diego_All.loc[San_Diego_All['Labels'] == 2]
sd_subset_4.shape
# Out:
# (9, 70)

# %%
# Combining the data for better visualizing results

# And map the clusters of reference
num_clusters = 8

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=9)

# set color scheme for the clusters
x = np.arange(num_clusters)
ys = [i + x + (i*x)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
# The venue Cluster
for lat, lon, poi, cluster in zip(sd_subset['Latitude'], sd_subset['Longitude'], sd_subset['ZipCode'], sd_subset['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=6,
        popup=label,
        color=rainbow[0],
        fill=True,
        fill_color=rainbow[0],
        fill_opacity=0.0).add_to(map_clusters)
       
# The demographic profil Cluster
for lat, lon, poi, cluster in zip(sd_subset_4['Latitude'], sd_subset_4['Longitude'], sd_subset_4['ZipCode'], sd_subset_4['Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=4,
        popup=label,
        color=rainbow[2],
        fill=True,
        fill_color=rainbow[2],
        fill_opacity=1.0).add_to(map_clusters)
# The succesful French Venue
for lat, lon, poi, cluster in zip(sd_subset_3['Latitude'], sd_subset_3['Longitude'], sd_subset_3['ZipCode'], sd_subset_3['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[7],
        fill=True,
        fill_color=rainbow[7],
        fill_opacity=0.0).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
